# %%
# Search similar properties
from vector_store import VectorStore
vs = VectorStore()
results = vs.search_similar("spacious 3BHK with parking", limit=5)
print(results)  
# Query database
from database import DatabaseHandler
db = DatabaseHandler()
property = db.get_property("PROP_001")
print(property['floorplan_parsed'])
# Out:
# Loading embedding model: sentence-transformers/all-mpnet-base-v2...
# ✓ Embedding model loaded
# [{'property_id': 'PROP-10067', 'title': 'Apartment for Sale in Nizamabad', 'score': 0.5999874, 'location': 'H.No. 988\nSarkar Path, Nizamabad, Jharkhand', 'price': 3217535}, {'property_id': 'PROP-10067', 'title': 'Apartment for Sale in Nizamabad', 'score': 0.5999874, 'location': 'H.No. 988\nSarkar Path, Nizamabad, Jharkhand', 'price': 3217535}, {'property_id': 'PROP-10001', 'title': 'House for Sale in Hyderabad', 'score': 0.5903705, 'location': '28/176, Sane, Hyderabad, Jharkhand', 'price': 48514810}, {'property_id': 'PROP-10001', 'title': 'House for Sale in Hyderabad', 'score': 0.5903705, 'location': '28/176, Sane, Hyderabad, Jharkhand', 'price': 48514810}, {'property_id': 'PROP-10065', 'title': 'Apartment for Sale in Dharmavaram', 'score': 0.5880629, 'location': 'H.No. 64, Tandon Ganj, Dharmavaram, Haryana', 'price': 32195143}]
# ...
